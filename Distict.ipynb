# %%
import pandas as pd

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import chi2_contingency
from scipy.stats import chi2

# %%
df = pd.read_csv("dist.csv")
df
# Out:
#     Sl. No          District  Normal (mm)  Actual (mm)  Departure (%)
# 0        1            Mandya          699         1484            112
# 1        2          Tumakuru          669         1358            103
# 2        3   Bengaluru Rural          798         1498             88
# 3        4        Ramanagara          840         1512             80
# 4        5        Davanagere          659         1162             76
# 5        6   Bengaluru Urban          846         1456             72
# 6        7             Kolar          735         1250             70
# 7        8             Gadag          624          995             60
# 8        9            Mysuru          837         1318             57
# 9       10       Chitradurga          540          839             55
# 10      11   Chikkaballapura          736         1134             54
# 11      12            Hassan         1142         1701             49
# 12      13   Chamarajanagara          787         1159             47
# 13      14          Belagavi          826         1194             45
# 14      15       Vijayanagar          643          927             44
# 15      16         Bagalkote          582          807             39
# 16      17           Dharwad          787         1051             34
# 17      18           Ballari          599          795             33
# 18      19            Yadgir          719          933             30
# 19      20        Vijayapura          591          760             29
# 20      21            Haveri          800         1023             28
# 21      22    Chikkamagaluru         1833         2278             24
# 22      23           Raichur          654          805             23
# 23      24           Koppala          614          744             21
# 24      25             Bidar          838          952             14
# 25      26            Kodagu         2729         3036             11
# 26      27        Kalaburagi          770          847             10
# 27      28  Dakshina Kannada         4006         4383              9
# 28      29        Shivamogga         2325         2439              5
# 29      30             Udupi         4535         4672              3
# 30      31    Uttara Kannada         2936         2981              2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sl. No         31 non-null     int64
#  1   District       31 non-null     object
#  2   Normal (mm)    31 non-null     int64
#  3   Actual (mm)    31 non-null     int64
#  4   Departure (%)  31 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 1.3+ KB

# %%
average_annual_rainfall = df.groupby('District')['Actual (mm)'].mean()
print(average_annual_rainfall)
# Out:
# District
# Bagalkote            807.0
# Ballari              795.0
# Belagavi            1194.0
# Bengaluru Rural     1498.0
# Bengaluru Urban     1456.0
# Bidar                952.0
# Chamarajanagara     1159.0
# Chikkaballapura     1134.0
# Chikkamagaluru      2278.0
# Chitradurga          839.0
# Dakshina Kannada    4383.0
# Davanagere          1162.0
# Dharwad             1051.0
# Gadag                995.0
# Hassan              1701.0
# Haveri              1023.0
# Kalaburagi           847.0
# Kodagu              3036.0
# Kolar               1250.0
# Koppala              744.0
# Mandya              1484.0
# Mysuru              1318.0
# Raichur              805.0
# Ramanagara          1512.0
# Shivamogga          2439.0
# Tumakuru            1358.0
# Udupi               4672.0
# Uttara Kannada      2981.0
# Vijayanagar          927.0
# Vijayapura           760.0
# Yadgir               933.0
# Name: Actual (mm), dtype: float64

# %%
highest_rainfall_district = df.loc[df['Actual (mm)'].idxmax()]
lowest_rainfall_district = df.loc[df['Actual (mm)'].idxmin()]

print("District with highest rainfall:")
print(highest_rainfall_district[['District', 'Actual (mm)']])

print("\nDistrict with lowest rainfall:")
print(lowest_rainfall_district[['District', 'Actual (mm)']])
# Out:
# District with highest rainfall:
# District       Udupi
# Actual (mm)     4672
# Name: 29, dtype: object
#
# District with lowest rainfall:
# District       Koppala
# Actual (mm)        744
# Name: 23, dtype: object

# %%
average_annual_rainfall.plot(figsize = (20,5))
# Out:
# <Axes: xlabel='District'>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your data is in a DataFrame named 'data'

# Create a line plot
plt.figure(figsize=(10, 6))
plt.plot(data['District'], data['Normal (mm)'], label='Normal Rainfall', marker='o')
plt.plot(data['District'], data['Actual (mm)'], label='Actual Rainfall', marker='x')
plt.title('Comparison of Normal and Actual Rainfall')
plt.xlabel('District')
plt.ylabel('Rainfall (mm)')
plt.legend()
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.hist(data['Actual (mm)'], bins=20, color='blue', alpha=0.7)
plt.title('Distribution of Actual Rainfall')
plt.xlabel('Actual Rainfall (mm)')
plt.ylabel('Frequency')
plt.show()

# %%
import pandas as pd

df = pd.read_csv("dist.csv")

# Calculate the average annual rainfall for each district
average_annual_rainfall = df.groupby('District')['Actual (mm)'].mean()

# Create a pie chart
plt.figure(figsize=(8, 8))
average_annual_rainfall.plot(kind='pie', autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Average Annual Rainfall')
plt.show()

# %%
pip install joypy
# Out:
# Collecting joypy
#   Obtaining dependency information for joypy from https://files.pythonhosted.org/packages/e9/8c/4d32c8935431eb10fd140faa4b13b6b8de222223a88fa9ad2a7711b7f1a9/joypy-0.2.6-py2.py3-none-any.whl.metadata
#   Downloading joypy-0.2.6-py2.py3-none-any.whl.metadata (812 bytes)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\darsh\anaconda\lib\site-packages (from joypy) (1.24.3)
# Requirement already satisfied: scipy>=0.11.0 in c:\users\darsh\anaconda\lib\site-packages (from joypy) (1.10.1)
# Requirement already satisfied: pandas>=0.20.0 in c:\users\darsh\anaconda\lib\site-packages (from joypy) (1.5.3)
# Requirement already satisfied: matplotlib in c:\users\darsh\anaconda\lib\site-packages (from joypy) (3.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\darsh\anaconda\lib\site-packages (from pandas>=0.20.0->joypy) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\darsh\anaconda\lib\site-packages (from pandas>=0.20.0->joypy) (2022.7)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\darsh\anaconda\lib\site-packages (from matplotlib->joypy) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\darsh\anaconda\lib\site-packages (from matplotlib->joypy) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\darsh\anaconda\lib\site-packages (from matplotlib->joypy) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\darsh\anaconda\lib\site-packages (from matplotlib->joypy) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\darsh\anaconda\lib\site-packages (from matplotlib->joypy) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\darsh\anaconda\lib\site-packages (from matplotlib->joypy) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\darsh\anaconda\lib\site-packages (from matplotlib->joypy) (3.0.9)
# Requirement already satisfied: six>=1.5 in c:\users\darsh\anaconda\lib\site-packages (from python-dateutil>=2.8.1->pandas>=0.20.0->joypy) (1.16.0)
# Downloading joypy-0.2.6-py2.py3-none-any.whl (8.6 kB)
# Installing collected packages: joypy
# Successfully installed joypy-0.2.6
# Note: you may need to restart the kernel to use updated packages.

# %%
# Create a heatmap
sns.set_theme()
sns.set(rc={'figure.figsize': (10, 8)})

heatmap = sns.heatmap(df[['District', 'Normal (mm)', 'Actual (mm)']].set_index('District'), annot=True, cmap='YlGnBu')
heatmap.set_title('Comparison of Normal and Actual Rainfall')
plt.show()

# %%
average_annual_rainfall = df.groupby('District')['Actual (mm)'].mean()

# Create a bar chart
plt.figure(figsize=(12, 6))
average_annual_rainfall.plot(kind='bar')
plt.title('Average Annual Rainfall by District')
plt.xlabel('District')
plt.ylabel('Average Annual Rainfall (mm)')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# Create a box plot
plt.figure(figsize=(10, 6))
df.boxplot(column='Actual (mm)', by='District', rot=45)
plt.title('Annual Rainfall Distribution by District')
plt.xlabel('District')
plt.ylabel('Annual Rainfall (mm)')
plt.show()
